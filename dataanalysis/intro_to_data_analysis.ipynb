# %% [markdown]
# ### import all data analysis libraries

# %%
import pandas as pd # the main library
import numpy as np # numerical expresion
import matplotlib.pyplot as plt # graphical charts
import seaborn as sns # enhanced charts 
import os # for checking paths

# %%
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'tableau-colorblind10']

# %%
plt.style.use('ggplot')

# %% [markdown]
# ### an example of visualization

# %%
names = ['raj','sonu','ajay','escobar']
marks = [100,50,70,25]

# %%
plt.bar(x=names,height=marks,color=['red','orange'])
plt.show()

# %% [markdown]
# # working with actual datasets using pandas

# %%
face_mask_df =  pd.read_csv('../web_scraping/flipcart_face_masks.csv',index_col=0)

# %%
face_mask_df['stars'].plot(kind='hist')
plt.show()

# %% [markdown]
# # types of graph in analysis
# graphs can be 2d or 3d
# - line
# - scatter
# - area
# - bar
# - hist
# - kde
# - boxplot
# - pie

# %%
irisdf = sns.load_dataset('iris')

# %%
irisdf
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # line plot
# - use to show ups and downs in s sequence or time series

# %%
irisdf['sepal_length'].plot(figsize=(15,5))

# %%
irisdf['sepal_length'].plot(figsize=(15,5),style='g--')
plt.show()

# %% [markdown]
# # scatter plot
# - to check the correlation of 2 or 3 series in a dataset

# %%
irisdf.plot(kind='scatter',x ='petal_length',y='petal_width')
plt.show()

# %%
irisdf.plot(kind='scatter',x ='petal_length',y='petal_width',
            c='petal_length',cmap='cool',marker='+',alpha=.5,
            s=100,title='compairing petals dimensions')
plt.xticks([])
plt.show()
